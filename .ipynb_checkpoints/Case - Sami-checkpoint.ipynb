# %%
import pandas as pd

# %%
df_vendedor = pd.read_excel('TESTE PRATICO_BaseDados.xlsx', sheet_name='TB_VENDEDOR')
df_vendedor
# Out:
#    ID_VENDEDOR NOME_VENDEDOR ESTADO
# 0            1    Vendedor 1     SP
# 1            2    Vendedor 2     RJ
# 2            3    Vendedor 3     PR
# 3            4    Vendedor 4     SP
# 4            5    Vendedor 5     MG
# 5            6    Vendedor 6     RJ
# 6            7    Vendedor 7     PR
# 7            8    Vendedor 8     SP
# 8            9    Vendedor 9     RJ
# 9           10   Vendedor 10     MG

# %%
df_vendas = pd.read_excel('TESTE PRATICO_BaseDados.xlsx', sheet_name='TB_VENDAS')
df_vendas
# Out:
#     ID_VENDA  ID_VENDEDOR  VALOR_VENDA_R$       DATA
# 0          1            7             579 2017-10-29
# 1          2            7             436 2017-11-11
# 2          3            1              56 2017-09-29
# 3          4            1              89 2017-11-03
# 4          5            2             546 2017-09-22
# 5          6            2             768 2017-09-29
# 6          7            2             120 2017-11-03
# 7          8            3             145 2017-06-10
# 8          9           10             278 2017-07-23
# 9         10           10              69 2017-10-27
# 10        11            3              87 2017-06-13
# 11        12            3             436 2017-07-23
# 12        13            1             167 2017-07-23
# 13        14            1             427 2017-08-10
# 14        15            5             985 2017-12-09
# 15        16            7             346 2017-08-10
# 16        17            9             129 2017-09-29
# ...
